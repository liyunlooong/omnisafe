# %%
# !pip install omnisafe

# %%
# !git clone https://github.com/liyunlooong/omnisafe.git
# %cd omnisafe
# !pip install -e .

# %%
# %cd examples
# !python train_from_yaml.py

# %%
# %cd ..

# %%
# !git config --global user.email "liyunlooong@outlook.com"
# !git config --global user.name "liyunlooong"
# !git add --all
# !git commit -m "update_CPPOPIDET"
# !git push https://liyunlooong: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@github.com/liyunlooong/omnisafe.git
# Out:
# [main 752576e] update_CPPOPIDET
#  6 files changed, 212 insertions(+), 2 deletions(-)
#  create mode 100644 omnisafe/algorithms/on_policy/early_terminated/cppo_pid_early_terminated.py
#  create mode 100644 omnisafe/configs/on-policy/CPPOPIDET.yaml
# Enumerating objects: 27, done.
# Counting objects: 100% (27/27), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (15/15), done.
# Writing objects: 100% (15/15), 3.79 KiB | 1.90 MiB/s, done.
# Total 15 (delta 11), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (11/11), completed with 11 local objects.
# To https://github.com/liyunlooong/omnisafe.git
#    6ca6c7b..752576e  main -> main
