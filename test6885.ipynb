# %%
# !pip install omnisafe

# %%
# !git clone https://github.com/liyunlooong/omnisafe.git
# %cd omnisafe
# !pip install -e .

# %%
# %cd examples
# !python train_from_yaml.py

# %% [markdown]
# 上面的通过改文件里的参数来修改
# 下面的通过命令行修改

# %%
# !python train_policy.py --algo PPOLagET --env-id SafetyPointGoal1-v0 --parallel 1 --total-steps 10000000 --device cpu --vector-env-nums 1 --torch-threads 1
